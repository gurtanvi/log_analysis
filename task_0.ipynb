# %% [markdown]
# <a href="https://colab.research.google.com/github/gurtanvi/task_01/blob/main/task_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# '20210212_131824 (1).jpg'              ' Paxos final_01.txt.gdoc'
#  20210212_131824.jpg                   ' Paxos final (1).txt.gdoc'
# 'Colab Notebooks'/                     ' Paxos final.txt.gdoc'
#  csv_creator.ipynb                     'Reference_Letter (1).pdf'
#  Deletionofexam_Gurleenkaur.gdoc       'reference letter.jpg'
#  Dokument.txt.gdoc                      Reference_Letter.pdf
#  euc_dist.gsheet                        Resume/
# 'exam 2016.txt.gdoc'                    TEMPLATE-ArgumenText-Timesheet.numbers
#  final_euc.gsheet                       Untitled1.ipynb
#  GalleryLock/                          'Untitled Diagram.drawio'
# 'Google Buzz'/                         'Untitled document (1).gdoc'
# 'Gurleen Kaur authority letter.jpg'    'Untitled document (2).gdoc'
# 'Implementation Plan.gdoc'             'Untitled document (3).gdoc'
#  Job/                                  'Untitled document.gdoc'
# ...

# %%
import pandas as pd
import numpy as np
import re as re

# %%
lines[98]
# Out:
# '[graphql] operation-responsetime | operation: onPatientEvent | duration: 0.939492066 | operationType: subscription\n'

# %%
logfile = open('logs.log', 'r')
lines = logfile.readlines()

# %%
len(lines)
# Out:
# 938

# %%
split_del=[]
for x in lines:
    split = len(x.split("|"))
    #print(split)
    split_del.append(split)
   # print(split_del)
print(np.unique(split_del))
# Out:
# [2 3 4 6]

# %%
len(log)
# Out:
# 0

# %%
len(log[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2c210c278106> in <module>()
# ----> 1 len(log[0])
#
# NameError: name 'log' is not defined

# %%
list3_0=[]
list3_1=[]
list3_2=[]
list2_0=[]
list2_1=[]
list4_3=[]
list4_2=[]
list4_1=[]
list4_0=[]
list6_5=[]
list6_4=[]
list6_3=[]
list6_2=[]
list6_1=[]
list6_0=[]

for column in lines:
 # # Change the colon except the first colon to another character first
  #print(len(column))
  if len(column.split("|"))==3:
      element2 = column.split("|")[2]
      element1 = column.split("|")[1]
      element0 = column.split("|")[0]
      list3_0.append(element0)
      list3_1.append(element1)
      list3_2.append(element2)

  elif len(column.split("|"))==2:
      element1 = column.split("|")[1]
      element0 = column.split("|")[0]
      list2_1.append(element1)
      list2_0.append(element0)

  elif len(column.split("|"))==4:
      element3 = column.split("|")[3]
      element2 = column.split("|")[2]
      element1 = column.split("|")[1]
      element0 = column.split("|")[0]
      list4_3.append(element3)
      list4_2.append(element2)
      list4_1.append(element1)
      list4_0.append(element2)

  elif len(column.split("|"))==6:
      element5 = column.split("|")[5]
      element4 = column.split("|")[4]
      element3 = column.split("|")[3]
      element2 = column.split("|")[2]
      element1 = column.split("|")[1]
      element0 = column.split("|")[0]
      list6_5.append(element5)
      list6_4.append(element4)
      list6_3.append(element3)
      list6_2.append(element2)
      list6_1.append(element1)
      list6_0.append(element0)
      #list_4.append(element4)
     # element0 = column.split("|")[0]
#  d = d.append(c,ignore_index=True)

# %%
list2_1
# Out:
# [' trigger: ON_CASE_DATA_CHANGE\n',
#  ' trigger: ON_DIGITAL_CONSULTATION_CHANGE\n',
#  ' trigger: ON_DIGITAL_CONSULTATION_CHANGE\n',
#  ' trigger: ON_EXPORT_FINISHED\n',
#  ' trigger: ON_EXPORT_FINISHED\n',
#  ' trigger: ON_PATIENT_CHANGE,ON_NOTE_CHANGE,ON_CASE_DATA_CHANGE,ON_DIGITAL_CONSULTATION_CHANGE\n',
#  ' trigger: ON_USER_CHANGE,ON_ROLE_CHANGE\n',
#  ' trigger: ON_PATIENT_CHANGE,ON_NOTE_CHANGE,ON_CASE_DATA_CHANGE,ON_DIGITAL_CONSULTATION_CHANGE\n',
#  ' trigger: ON_PATIENT_CHANGE,ON_NOTE_CHANGE,ON_CASE_DATA_CHANGE,ON_DIGITAL_CONSULTATION_CHANGE\n',
#  ' trigger: ON_PATIENT_CHANGE,ON_NOTE_CHANGE,ON_CASE_DATA_CHANGE,ON_DIGITAL_CONSULTATION_CHANGE\n',
#  ' trigger: ON_PATIENT_CHANGE,ON_NOTE_CHANGE,ON_CASE_DATA_CHANGE,ON_DIGITAL_CONSULTATION_CHANGE\n',
#  ' trigger: ON_PATIENT_CHANGE,ON_NOTE_CHANGE,ON_CASE_DATA_CHANGE,ON_DIGITAL_CONSULTATION_CHANGE\n',
#  ' trigger: ON_USER_CHANGE,ON_ROLE_CHANGE\n',
#  ' trigger: ON_CASE_DATA_CHANGE\n',
# ...

# %%
list3_0=[]
for column in lines:
 # # Change the colon except the first colon to another character first
  #print(len(column))
  if len(column.split("|"))==3:
      element2 = column.split("|")[2]
      element1 = column.split("|")[1]
      element0 = column.split("|")[0]
      list3_0.append(element0)

# %%
len(list6_0)
# Out:
# 8

# %%
print(list3_2)
# Out:
# [' opId: 118\n', ' opId: 119\n', ' opId: 120\n', ' opId: 121\n', ' opId: 122\n', ' opId: 123\n', ' opId: 124\n', ' opId: 125\n', ' opId: 126\n', ' opId: 127\n', ' opId: 128\n', ' opId: 129\n', ' opId: 130\n', ' opId: 131\n', ' opId: 132\n', ' opId: 133\n', ' opId: 134\n', ' opId: 135\n', ' opId: 136\n', ' opId: 137\n', ' opId: 138\n', ' opId: 139\n', ' opId: 140\n', ' opId: 141\n', ' opId: 142\n', ' opId: 143\n', ' opId: 144\n', ' opId: 145\n', ' opId: 146\n', ' opId: 147\n', ' opId: 148\n', ' opId: 149\n', ' opId: 150\n', ' opId: 151\n', ' opId: 152\n', ' opId: 153\n', ' opId: 154\n', ' opId: 155\n', ' opId: 156\n', ' opId: 157\n', ' opId: 158\n', ' opId: 159\n', ' opId: 160\n', ' opId: 161\n', ' opId: 162\n', ' opId: 163\n', ' opId: 164\n', ' opId: 165\n', ' opId: 166\n', ' opId: 167\n', ' opId: 168\n', ' opId: 169\n', ' opId: 170\n', ' opId: 171\n', ' opId: 172\n', ' opId: 173\n', ' opId: 174\n', ' opId: 175\n', ' opId: 176\n', ' opId: 177\n', ' opId: 178\n', ' opId: 179\n', ' opI
# ...

# %%
list2_0[:]

# %%
list4_3[:]
# Out:
# [' operationType: query\n',
#  ' operationType: subscription\n',
#  ' operationType: subscription\n',
#  ' operationType: subscription\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: subscription\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: subscription\n',
#  ' operationType: subscription\n',
#  ' operationType: query\n',
#  ' operationType: subscription\n',
#  ' operationType: subscription\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: query\n',
#  ' operationType: subscription\n',
#  ' operationType: subscription\n',
#  ' operationType: subscription\n',
#  ' operationType: query\n',
# ...

# %%
newlist_mut = list(filter(r_mutation.match, list4_3)) # Read Note below
#print(newlist)
len(newlist_mut)
#newlist_mut[:]
# Out:
# 28

# %%
newlist_query = list(filter(r_query.match, list4_3)) # Read Note below
#print(newlist)
len(newlist_query)
#newlist_query[:]
# Out:
# 362

# %%
newlist_subs = list(filter(r_subs.match, list4_3)) # Read Note below
#print(newlist)
len(newlist_subs)
#newlist_subs[:]
# Out:
# 33

# %%
import re

# %%
r_mutation = re.compile(".*mutation")

# %%
r_query = re.compile(".*query")

# %%
r_subs = re.compile(".*subscription")

# %%
regex = r"query|subscription|mutation"

# %%
list3_1
# Out:
# [' operation: SearchPatients ',
#  ' operation: GetStatistics ',
#  ' operation: GetExporterTemplates ',
#  ' operation: onExportFinished ',
#  ' operation: GetExporterObjects ',
#  ' operation: GetFormOptions ',
#  ' operation: Institute ',
#  ' operation: SearchPatients ',
#  ' operation: onPatientEvent ',
#  ' operation: onMeChange ',
#  ' operation: Institute ',
#  ' operation: Patient ',
#  ' operation: onPatientEvent ',
#  ' operation: CaseOverview ',
#  ' operation: Scores ',
#  ' operation: Timeline ',
#  ' operation: onPatientEvent ',
#  ' operation: DigitalConsultation ',
#  ' operation: GetFormOptions ',
#  ' operation: onCaseEvent ',
#  ' operation: DashboardCases ',
#  ' operation: onDigitalConsultationEvent ',
#  ' operation: DashboardDigitalConsultations ',
#  ' operation: onDigitalConsultationEvent ',
#  ' operation: DashboardDigitalConsultations ',
#  ' operation: DashboardMeta ',
#  ' operation: onPatientEvent ',
#  ' operation: onMeChange ',
# ...

# %%
np.unique(list3_1)
# Out:
# array([' operation: CaseOverview ', ' operation: ConnectorState ',
#        ' operation: DashboardCases ',
#        ' operation: DashboardDigitalConsultations ',
#        ' operation: DashboardMeta ', ' operation: Devices ',
#        ' operation: DigitalConsultation ', ' operation: Documentation ',
#        ' operation: GetExporterObjects ',
#        ' operation: GetExporterTemplates ', ' operation: GetFormOptions ',
#        ' operation: GetFormOptionsById ', ' operation: GetStatistics ',
#        ' operation: Institute ', ' operation: Patient ',
#        ' operation: Scores ', ' operation: SearchCases ',
#        ' operation: SearchPatients ', ' operation: Timeline ',
#        ' operation: User ', ' operation: UserList ',
#        ' operation: createCase ',
#        ' operation: createDigitalConsultation ',
#        ' operation: createDocumentation ',
#        ' operation: getPermissionsGroups ', ' operation: getRoles ',
#        ' operation: onCaseEvent ',
# ...

# %%
r_operation = re.compile(".operation*")

# %%
newlist_operation = list(filter(r_operation.match, list3_1)) # Read Note below
print(newlist_operation)
np.unique(newlist_operation)
#newlist_subs[:]
# Out:
# [' operation: SearchPatients ', ' operation: GetStatistics ', ' operation: GetExporterTemplates ', ' operation: onExportFinished ', ' operation: GetExporterObjects ', ' operation: GetFormOptions ', ' operation: Institute ', ' operation: SearchPatients ', ' operation: onPatientEvent ', ' operation: onMeChange ', ' operation: Institute ', ' operation: Patient ', ' operation: onPatientEvent ', ' operation: CaseOverview ', ' operation: Scores ', ' operation: Timeline ', ' operation: onPatientEvent ', ' operation: DigitalConsultation ', ' operation: GetFormOptions ', ' operation: onCaseEvent ', ' operation: DashboardCases ', ' operation: onDigitalConsultationEvent ', ' operation: DashboardDigitalConsultations ', ' operation: onDigitalConsultationEvent ', ' operation: DashboardDigitalConsultations ', ' operation: DashboardMeta ', ' operation: onPatientEvent ', ' operation: onMeChange ', ' operation: Institute ', ' operation: Patient ', ' operation: onPatientEvent ', ' operation: CaseOvervi
# ...

# %%
(unique_op, counts_op) = np.unique(newlist_operation, return_counts=True)
frequencies = np.asarray((unique_op, counts_op)).T
print(frequencies)
# Out:
# [[' operation: CaseOverview ' '5']
#  [' operation: ConnectorState ' '1']
#  [' operation: DashboardCases ' '3']
#  [' operation: DashboardDigitalConsultations ' '6']
#  [' operation: DashboardMeta ' '3']
#  [' operation: Devices ' '2']
#  [' operation: DigitalConsultation ' '6']
#  [' operation: Documentation ' '3']
#  [' operation: GetExporterObjects ' '1']
#  [' operation: GetExporterTemplates ' '1']
#  [' operation: GetFormOptions ' '6']
#  [' operation: GetFormOptionsById ' '1']
#  [' operation: GetStatistics ' '1']
#  [' operation: Institute ' '5']
#  [' operation: Patient ' '9']
#  [' operation: Scores ' '5']
#  [' operation: SearchCases ' '137']
#  [' operation: SearchPatients ' '146']
#  [' operation: Timeline ' '8']
#  [' operation: User ' '1']
#  [' operation: UserList ' '3']
#  [' operation: createCase ' '1']
#  [' operation: createDigitalConsultation ' '1']
#  [' operation: createDocumentation ' '1']
#  [' operation: getPermissionsGroups ' '4']
# ...

# %%
df = pd.DataFrame(list(zip(lst, lst2)),
               columns =['Name', 'val'])

# %%
df = pd.DataFrame(list(zip(list4_1, list4_2,list4_3)),
               columns =['operation', 'duration', 'operaziontype'])

# %%
df
# Out:
#                                     operation  ...                       operaziontype
# 0                  operation: SearchPatients   ...              operationType: query\n
# 1                     operation: onCaseEvent   ...       operationType: subscription\n
# 2      operation: onDigitalConsultationEvent   ...       operationType: subscription\n
# 3      operation: onDigitalConsultationEvent   ...       operationType: subscription\n
# 4            operation: GetExporterTemplates   ...              operationType: query\n
# ..                                        ...  ...                                 ...
# 421                       operation: Patient   ...              operationType: query\n
# 422  warn] ignored trigger with empty result   ...   flowgraph: Client_Test_Caseflow\n
# 423                        operation: Scores   ...              operationType: query\n
# 424                      operation: Timeline   ...              operationType: query\n
# ...

# %%
list4_1
# Out:
# [' operation: SearchPatients ',
#  ' operation: onCaseEvent ',
#  ' operation: onDigitalConsultationEvent ',
#  ' operation: onDigitalConsultationEvent ',
#  ' operation: GetExporterTemplates ',
#  ' operation: GetExporterObjects ',
#  ' operation: GetStatistics ',
#  ' operation: onExportFinished ',
#  ' operation: GetFormOptions ',
#  ' operation: Institute ',
#  ' operation: SearchPatients ',
#  ' operation: Institute ',
#  ' operation: Patient ',
#  ' operation: Timeline ',
#  ' operation: Scores ',
#  ' operation: CaseOverview ',
#  ' operation: DigitalConsultation ',
#  ' operation: onPatientEvent ',
#  ' operation: onPatientEvent ',
#  ' operation: GetFormOptions ',
#  ' operation: onPatientEvent ',
#  ' operation: onMeChange ',
#  ' operation: DashboardMeta ',
#  ' operation: DashboardCases ',
#  ' operation: DashboardDigitalConsultations ',
#  ' operation: DashboardDigitalConsultations ',
#  ' operation: onCaseEvent ',
#  ' operation: onDigitalConsultationEvent ',
# ...
